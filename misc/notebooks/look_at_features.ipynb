# %%
from tensorflow.io import gfile
import joblib
import os

! export BUCKET_ID=ideal-pancake

! export PROJECT_ID=ideal-pancake
! export GOOGLE_APPLICATION_CREDENTIALS=credentials/ideal-pancake-google-application-credentials.json

# %%
def download_premade_features(name):
    features_path = os.path.join("pregenerated-features", name, "features")
    features, labels = download_object(features_path)
    return features, labels



def download_object(path):
    bucket_path = f"gs://{path}"
    with gfile.GFile(bucket_path, "rb") as wf:
        obj = joblib.load(wf)
    return obj

# %%
df, labels = download_premade_features("emip-fixations")

# %%
df
# Out:
#      pupil_diameter_rolling__fft_aggregated__aggtype_"centroid"  \
# 1                                             6.675719
# 2                                            61.581099
# 3                                            21.282758
# 4                                            29.188434
# 5                                            13.441829
# ..                                                 ...
# 212                                          26.197807
# 213                                          33.651262
# 214                                          30.248128
# 215                                          35.283299
# 216                                          27.517641
#
#      pupil_diameter_rolling__fft_aggregated__aggtype_"variance"  \
# 1                                          1428.078143
# 2                                         35212.290989
# 3                                          3689.993266
# 4                                          5200.375297
# 5                                          2214.954879
# ..                                                 ...
# 212                                        5818.786499
# 213                                       12003.590504
# 214                                        9954.177939
# 215                                        7422.713163
# 216                                       12974.608955
#
#      pupil_diameter_rolling__fft_aggregated__aggtype_"skew"  \
# 1                                             9.460178
# 2                                             4.011979
# 3                                             3.599808
# 4                                             3.125038
# 5                                             4.578260
# ..                                                 ...
# 212                                           3.748941
# 213                                           4.226072
# 214                                           4.483756
# 215                                           3.030232
# 216                                           6.303944
#
#      pupil_diameter_rolling__fft_aggregated__aggtype_"kurtosis"  \
# 1                                           105.634293
# 2                                            19.492577
# 3                                            16.012282
# 4                                            12.524421
# 5                                            24.872382
# ..                                                 ...
# 212                                          17.256272
# 213                                          21.450514
# 214                                          24.024822
# 215                                          11.871006
# 216                                          46.444128
#
#      pupil_diameter_rolling__yolo  pupil_diameter_rolling__lhipa  \
# 1                            69.0                      22.500000
# 2                            69.0                      10.777778
# 3                            69.0                      28.500000
# 4                            69.0                      21.000000
# 5                            69.0                      25.000000
# ..                            ...                            ...
# 212                          69.0                      24.000000
# 213                          69.0                      22.600000
# 214                          69.0                      22.400000
# 215                          69.0                      24.333333
# 216                          69.0                      10.625000
#
#      pupil_diameter_rolling__arma__exog  pupil_diameter_rolling__arma__ar  \
# 1                              0.556877                          2.266646
# 2                              0.336145                          2.396439
# 3                              0.464008                          1.774093
# 4                              0.311983                          1.979856
# 5                              0.558287                          1.966041
# ..                                  ...                               ...
# 212                            0.311898                          1.905082
# 213                            0.439548                          1.963281
# 214                            0.403536                          1.932676
# 215                            0.441950                          1.918613
# 216                            0.375346                          1.930538
#
#      pupil_diameter_rolling__arma__ma  pupil_diameter_rolling__garch__mu  ...  \
# 1                           -1.563457                           0.525310  ...
# 2                           -1.802093                           0.241059  ...
# 3                           -0.775384                           0.493905  ...
# 4                           -0.980070                           0.209034  ...
# 5                           -0.966423                           0.675708  ...
# ..                                ...                                ...  ...
# 212                         -0.905765                           0.285545  ...
# 213                         -0.963733                           0.442213  ...
# 214                         -0.933800                           0.405676  ...
# 215                         -0.918979                           0.433013  ...
# 216                         -0.931094                           0.343355  ...
#
#      heatmaps_153594  heatmaps_153595  heatmaps_153596  heatmaps_153597  \
# 1                0.0         0.000000              0.0              0.0
# 2                0.0         0.000000              0.0              0.0
# 3                0.0         0.000000              0.0              0.0
# 4                0.0         0.000000              0.0              0.0
# 5                0.0         0.984054              0.0              0.0
# ..               ...              ...              ...              ...
# 212              0.0         0.107714              0.0              0.0
# 213              0.0         0.000000              0.0              0.0
# 214              0.0         0.000000              0.0              0.0
# 215              0.0         0.000000              0.0              0.0
# 216              0.0         0.000000              0.0              0.0
#
#      heatmaps_153598  heatmaps_153599  information_processing_ratio  \
# 1                0.0              0.0                      1.233333
# 2                0.0              0.0                      1.932836
# 3                0.0              0.0                      0.923077
# 4                0.0              0.0                      0.785714
# 5                0.0              0.0                      0.952381
# ..               ...              ...                           ...
# 212              0.0              0.0                      1.387755
# 213              0.0              0.0                      1.295775
# 214              0.0              0.0                      1.195652
# 215              0.0              0.0                      0.666667
# 216              0.0              0.0                      1.150000
#
#      saccade_speed_skewness  entropy_xy  saccade_verticality
# 1                  2.657448    4.753290             0.716318
# 2                  3.992829    4.836342             0.668098
# 3                  1.284298    4.865230             0.556782
# 4                  0.836274    4.770260             0.465681
# 5                  1.091256    4.843480             0.441959
# ..                      ...         ...                  ...
# 212                2.028952    4.433929             0.622897
# 213                1.499671    5.069312             0.596231
# 214                1.064565    4.958130             0.543583
# 215                1.461494    4.740518             0.546822
# 216                2.276773    4.904516             0.678317
#
# [216 rows x 153916 columns]

# %%
df.filter(regex=("^(?!heatmaps)")).to_csv("features_emip.csv")
