# %%
from tensorflow.io import gfile
import joblib
import os

! export BUCKET_ID=ideal-pancake

! export PROJECT_ID=ideal-pancake
! export GOOGLE_APPLICATION_CREDENTIALS=credentials/ideal-pancake-google-application-credentials.json

# %%
def download_premade_features(name):
    features_path = os.path.join("pregenerated-features", name, "features")
    features, labels = download_object(features_path)
    return features, labels



def download_object(path):
    bucket_path = f"gs://{path}"
    with gfile.GFile(bucket_path, "rb") as wf:
        obj = joblib.load(wf)
    return obj

# %%
df, labels = download_premade_features("emip-enhanced")

# %%
df
# Out:
#      pupil_diameter__fft_aggregated__aggtype_"centroid"  \
# 208                                         574.478056
# 213                                         867.709526
# 63                                          957.512433
# 197                                         528.065207
# 97                                          574.902813
# ..                                                 ...
# 210                                         306.007491
# 156                                          67.228464
# 145                                         891.683826
# 202                                        1439.562484
# 121                                         323.195675
#
#      pupil_diameter__fft_aggregated__aggtype_"variance"  \
# 208                                       4.256331e+06
# 213                                       7.732631e+06
# 63                                        1.036594e+07
# 197                                       4.482463e+06
# 97                                        4.398874e+06
# ..                                                 ...
# 210                                       1.383190e+06
# 156                                       1.237897e+05
# 145                                       8.472077e+06
# 202                                       2.217906e+07
# 121                                       1.517110e+06
#
#      pupil_diameter__fft_aggregated__aggtype_"skew"  \
# 208                                        4.696255
# 213                                        4.233130
# 63                                         4.452325
# 197                                        5.024762
# 97                                         4.706169
# ..                                              ...
# 210                                        5.025743
# 156                                        6.882977
# 145                                        4.352674
# 202                                        4.127245
# 121                                        4.876761
#
#      pupil_diameter__fft_aggregated__aggtype_"kurtosis"  \
# 208                                          25.941996
# 213                                          21.483465
# 63                                           23.628530
# 197                                          29.133750
# 97                                           26.032692
# ..                                                 ...
# 210                                          29.538341
# 156                                          53.722375
# 145                                          22.675655
# 202                                          20.321430
# 121                                          27.737556
#
#      pupil_diameter__lhipa  pupil_diameter__arima__exog  \
# 208               5.025000                     0.000002
# 213               2.620000                     0.996917
# 63                2.535912                     0.944358
# 197               2.523438                    -0.159090
# 97                5.155738                     0.884365
# ..                     ...                          ...
# 210               5.013889                     0.823966
# 156              10.714286                     0.000002
# 145               2.559006                     0.956606
# 202               2.555102                     0.192891
# 121               5.273973                     0.550194
#
#      pupil_diameter__arima__ar  pupil_diameter__arima__ma  \
# 208                   0.000002                   0.000043
# 213                  -0.915500                   0.000045
# 63                   -0.867935                   0.000045
# 197                   0.052288                   0.000024
# 97                   -0.884071                   0.000035
# ..                         ...                        ...
# 210                  -0.795727                   0.000036
# 156                   0.000002                   0.000038
# 145                  -0.849035                   0.000074
# 202                  -0.213592                   0.000031
# 121                  -0.587916                   0.000036
#
#      pupil_diameter__garch__mu  pupil_diameter__garch__omega  ...  \
# 208                   3.185795                      0.000354  ...
# 213                   3.100536                      0.000644  ...
# 63                    3.404513                      0.000539  ...
# 197                   2.866201                      0.001580  ...
# 97                    3.199848                      0.000356  ...
# ..                         ...                           ...  ...
# 210                   2.871896                      0.000283  ...
# 156                   3.671414                      0.000575  ...
# 145                   3.803769                      0.001109  ...
# 202                   3.100111                      0.000399  ...
# 121                   2.800463                      0.010092  ...
#
#      pupil_diameter__markov__90  pupil_diameter__markov__91  \
# 208                         0.0                         0.0
# 213                         0.0                         0.0
# 63                          0.0                         0.0
# 197                         0.0                         0.0
# 97                          0.0                         0.0
# ..                          ...                         ...
# 210                         0.0                         0.0
# 156                         0.0                         0.0
# 145                         0.0                         0.0
# 202                         0.0                         0.0
# 121                         0.0                         0.0
#
#      pupil_diameter__markov__92  pupil_diameter__markov__93  \
# 208                         0.0                         0.0
# 213                         0.0                         0.0
# 63                          0.0                         0.0
# 197                         0.0                         0.0
# 97                          0.0                         0.0
# ..                          ...                         ...
# 210                         0.0                         0.0
# 156                         0.0                         0.0
# 145                         0.0                         0.0
# 202                         0.0                         0.0
# 121                         0.0                         0.0
#
#      pupil_diameter__markov__94  pupil_diameter__markov__95  \
# 208                         0.0                         0.0
# 213                         0.0                         0.0
# 63                          0.0                         0.0
# 197                         0.0                         0.0
# 97                          0.0                         0.0
# ..                          ...                         ...
# 210                         0.0                         0.0
# 156                         0.0                         0.0
# 145                         0.0                         0.0
# 202                         0.0                         0.0
# 121                         0.0                         0.0
#
#      pupil_diameter__markov__96  pupil_diameter__markov__97  \
# 208                         0.0                         0.0
# 213                         0.0                         0.0
# 63                          0.0                         0.0
# 197                         0.0                         0.0
# 97                          0.0                         0.0
# ..                          ...                         ...
# 210                         0.0                         0.0
# 156                         0.0                         0.0
# 145                         0.0                         0.0
# 202                         0.0                         0.0
# 121                         0.0                         0.0
#
#      pupil_diameter__markov__98  pupil_diameter__markov__99
# 208                         0.0                         0.0
# 213                         0.0                         0.0
# 63                          0.0                         0.0
# 197                         0.0                         0.0
# 97                          0.0                         0.0
# ..                          ...                         ...
# 210                         0.0                         0.0
# 156                         0.0                         0.0
# 145                         0.0                         0.0
# 202                         0.0                         0.0
# 121                         0.0                         0.0
#
# [216 rows x 113 columns]
